# %% [markdown]
# # Run this before doing anything else!

# %%
from pymol import cmd
from utils import draw

# %% [markdown]
# # Loading the AlphaFold structure
# The name of the object is usually just the filename but without the .cif or .cif.gz at the end
#
#
# We are renaming it to `alphafold` to make it easier to work with later

# %%
cmd.load("REPLACE WITH NAME OF FILE")
cmd.rename("REPLACE WITH NAME OF OBJECT", "alphafold")
draw()

# %% [markdown]
# # Loading the CryoEM Structure
# Add your code above the `draw()`. Remember, the object should be renamed to `bsmv`
#
#
# Hint: look at what we did above

# %%
draw()

# %% [markdown]
# # Aligning the structures
# Add the code on the board. Make sure it is all before the `draw()`

# %%
draw()
