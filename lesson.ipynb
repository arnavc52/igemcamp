# %%
# Ignore this stuff over here
from pymol import cmd
from utils import draw

# %% [markdown]
# # Loading the CryoEM structure

# %%
cmd.load("REPLACE WITH NAME OF FILE")
# The name of the object is usually just the filename but without the .cif at the end
# We are renaming it to "model" to make it easier to work with later
cmd.rename("REPLACE WITH NAME OF OBJECT", "model")
draw()

# %% [markdown]
# # Loading the AlphaFold Structure

# %%
# Replace with your code. 
# Hint: look at what we did above
# The object should be renabed
draw()

# %% [markdown]
# # Aligning the structures

# %%
# Replace with the code on the board
draw()
